# %%
from sympy import *
import numpy as np

# %%
f = lambda x: sin(x)
a = 0
b = np.pi
h = (b - a) / 10
n = 11

X = np.linspace(0, np.pi, 11)
Y = [ f(x) for x in X ]
# for x in X:
#     print(x)
# for y in Y:
#     print(y)

# %%
sum( [ (X[i] - X[i-1]) * (Y[i] + Y[i-1]) / 2 for i in range(1, n)])     #I
# Out:
# 1.98352353750945

# %%
x = symbols('x')
M2 = abs(f(x).diff(x, 2))
plot(M2, (x, a, b))

# %%
M2 = 1
M2 * (b - a)**3 / (12 * (n-1)**2)       # sai số
# Out:
# 0.025838563900249845
